# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import integrate
import itertools

# %%
points = ([0, 10, 100], [1, 60, 50])


"""
x1000 x y500の正方形を4等分(X)する
 位置関係
属性a  属性b
属性c  属性d
"""

def get_sp_class(points):
   # box to append idx
   box_a, box_b, box_c, box_d = [],[],[],[]

   # equation y=ax+b
   #eq_rightup
   yr = 1/2*x

   #eq_leftup
   yl = -1/2*x + 500


   for

   return box_a

# %%
points = ([0, 10, 100], [1, 60, 50])

# box to append idx
class_wus = []
class_EPFL = []
class3 = []

# x1000 x y500の正方形を4等分する
位置関係は
属性a  属性b
属性c  属性d

x = 2 #temp



y_wus = 3*x + 5
y_epf = 3*x + 5
y_clv = 3*x + 5



if x < 100 or 150 < x\
   and y_wus < 100:
   print(x)


if -100 < x < 100 and y_wus < 100:
   print(y_wus)
# Out:
# 2
# 11

# %%
"""
points


idx はenumerateで得ればよい
↓

[idx, x, y]

[0, 10, 100]
[1, 60, 50]

↑

xとyから属性を取得

属性a = []
属性b = []
属性c = []


if 属性a → 属性a.append(idx)





"""
# Out:
# '\npoints\n\n\nidx はenumerateで得ればよい\n↓\n\n[idx, x, y]\n\n[0, 10, 100]\n[1, 60, 50]\n\n↑\n\nxとyから属性を取得\n\n属性a = []\n属性b = []\n属性c = []\n\n\nif 属性a → 属性a.append(idx)\n\n\n\n\n\n'
