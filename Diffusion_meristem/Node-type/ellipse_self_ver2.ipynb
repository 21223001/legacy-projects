# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import integrate
import itertools

# %%
"""Concept
selfver1では左下から点を等距離で作成した
よって右下の点が左下の点とyが合わない=左右対象ではない
そこで、左右にy0の点を固定して、目標の距離に
　なるまで弧を分割する事を目指す


2点を固定

k-means的にできないか？

"""
