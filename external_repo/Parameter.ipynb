# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os
import glob
import matplotlib.pyplot as plt
import re
import pandas as pd
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Sim_data= pd.read_csv('drive/My Drive/Colab Notebooks/Diffusion-ish/Sim_Param.csv')

# %%
Sim_data.head()
# Out:
#    ID  K_CW  n_CW  k_Cr  K_CL  n_CL  K_CH  n_CH  k_Cp  b_Cr  ...  n_HW  b_pp  \
# 0   1   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
# 1   2   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
# 2   3   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
# 3   4   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
# 4   5   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
#
#    k_pp  b_Hh  k_Hh  k_Ll  b_Ll   D_Ww  D_Cc  D_Ll
# 0     1     1     1    10   1.5  0.100  6.00   1.2
# 1     1     1     1    10   1.5  0.010  6.00   1.2
# 2     1     1     1    10   1.5  0.001  6.00   1.2
# 3     1     1     1    10   1.5  1.000  0.60   1.2
# 4     1     1     1    10   1.5  1.000  0.06   1.2
#
# [5 rows x 36 columns]

# %%
"""
for index, row in data.iterrows():
    print(row['Parameter'], '=', row['Value'])
"""

Sim_Param_ttt = []

for index, row in Sim_data.iterrows():


    Sim_Param = row['ID'], row['K_CW'], row['n_CW'], row['k_Cr'], row['K_CL'], row['n_CL'], row['K_CH'], row['n_CH'], row['k_Cp'], row['b_Cr'], row['b_Wr'], row['k_WL'], row['k_WC'], row['k_Wr'],\
         row['K_WW'], row['n_WW'], row['K_WL'], row['n_WL'], row['K_WC'], row['n_WC'], row['k_Wp'], row['b_Ww'], row['b_Wr'], row['ki_W'], row['a_Cc'], row['K_HW'], row['n_HW'], row['b_pp'],\
         row['k_pp'], row['b_Hh'], row['k_Hh'], row['k_Ll'], row['b_Ll'], row['D_Ww'], row['D_Cc'], row['D_Ll']

    #print(bc)
    Sim_Param_list = list(Sim_Param)
    #print(bc_list)
    Sim_Param_ttt.append(Sim_Param_list)

print(Sim_Param_ttt)
# Out:
# [[1.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.1, 6.0, 1.2], [2.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.01, 6.0, 1.2], [3.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.001, 6.0, 1.2], [4.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 0.6, 1.2], [5.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 0.06, 1.2], [6.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 0.006, 1.2], [7.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 6.0, 0.12], [8.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 6.0, 0.012], [9.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 1.0, 6.0, 0.001], [10.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.1, 0.6, 0.12], [11.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.01, 0.06, 0.012], [12.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.001, 0.006, 0.001], [13.0, 0.2, 6.0, 0.5, 0.24, 6.0, 0.13, 5.0, 2.7, 1.0, 0.5, 1.0, 1.0, 1.2, 0.53, 0.2, 0.29, 6.0, 0.1, 6.0, 0.345, 0.4, 0.5, 0.3, 1e-05, 0.3, 4.0, 1.0, 1.0, 1.0, 1.0, 10.0, 1.5, 0.0, 0.0, 0.0]]

# %%
def temp_opt(Sim_Param_ttt):
    #print(bc_ttt)

    Param_opt = []

    for n in range(13):
        Param_opt = Sim_Param_ttt[n]

        ID, K_CW, n_CW, k_Cr, K_CL, n_CL, K_CH, n_CH, k_Cp, b_Cr, b_Wr, k_WL, k_WC, k_Wr, K_WW, n_WW, K_WL, n_WL, K_WC, n_WC, k_Wp, b_Ww, b_Wr, ki_W, a_Cc, K_HW, n_HW, b_pp, k_pp, b_Hh, k_Hh, k_Ll, b_Ll, D_Ww, D_Cc, D_Ll =\
        Param_opt[0], Param_opt[1], Param_opt[2], Param_opt[3], Param_opt[4], Param_opt[5], Param_opt[6], Param_opt[7], Param_opt[8], Param_opt[9], \
        Param_opt[10], Param_opt[11], Param_opt[12], Param_opt[13], Param_opt[14], Param_opt[15], Param_opt[16], Param_opt[17], Param_opt[18], Param_opt[19], \
        Param_opt[20], Param_opt[21], Param_opt[22], Param_opt[23], Param_opt[24], Param_opt[25], Param_opt[26], Param_opt[27], Param_opt[28], Param_opt[29], \
        Param_opt[30], Param_opt[31], Param_opt[32], Param_opt[33], Param_opt[34], Param_opt[35]

        #print(Param_opt)
        print(ID)

    return

# %%
temp_opt(Sim_Param_ttt)

# %%
#以下

# %%
abc_idx = Sim_data[1:1]
print(abc_idx)

abc_par = Sim_data[0:1]
print(abc_par)

print(type(abc_idx))
print(type(abc_par))

abc_list = []

for n in abc_idx:
    #print(n)
    abc_list.append(n[0:4])

print(abc_list)

abc_list_par = []
for n in abc_par:
    #print(n)
    abc_list_par.append(n)

print(abc_list_par)
# Out:
# Empty DataFrame
# Columns: [ID, K_CW, n_CW, k_Cr, K_CL, n_CL, K_CH, n_CH, k_Cp, b_Cr, b_Wr, k_WL, k_WC, k_Wr, K_WW, n_WW, K_WL, n_WL, K_WC, n_WC, k_Wp, b_Ww, b_Wr.1, ki_W, a_Cc, K_HW, n_HW, b_pp, k_pp, b_Hh, k_Hh, k_Ll, b_Ll, D_Ww, D_Cc, D_Ll]
# Index: []
#
# [0 rows x 36 columns]
#    ID  K_CW  n_CW  k_Cr  K_CL  n_CL  K_CH  n_CH  k_Cp  b_Cr  ...  n_HW  b_pp  \
# 0   1   0.2     6   0.5  0.24     6  0.13     5   2.7     1  ...     4     1
#
#    k_pp  b_Hh  k_Hh  k_Ll  b_Ll  D_Ww  D_Cc  D_Ll
# 0     1     1     1    10   1.5   0.1   6.0   1.2
#
# [1 rows x 36 columns]
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# ['ID', 'K_CW', 'n_CW', 'k_Cr', 'K_CL', 'n_CL', 'K_CH', 'n_CH', 'k_Cp', 'b_Cr', 'b_Wr', 'k_WL', 'k_WC', 'k_Wr', 'K_WW', 'n_WW', 'K_WL', 'n_WL', 'K_WC', 'n_WC', 'k_Wp', 'b_Ww', 'b_Wr', 'ki_W', 'a_Cc', 'K_HW', 'n_HW', 'b_pp', 'k_pp', 'b_Hh', 'k_Hh', 'k_Ll', 'b_Ll', 'D_Ww', 'D_Cc', 'D_Ll']
# ['ID', 'K_CW', 'n_CW', 'k_Cr', 'K_CL', 'n_CL', 'K_CH', 'n_CH', 'k_Cp', 'b_Cr', 'b_Wr', 'k_WL', 'k_WC', 'k_Wr', 'K_WW', 'n_WW', 'K_WL', 'n_WL', 'K_WC', 'n_WC', 'k_Wp', 'b_Ww', 'b_Wr.1', 'ki_W', 'a_Cc', 'K_HW', 'n_HW', 'b_pp', 'k_pp', 'b_Hh', 'k_Hh', 'k_Ll', 'b_Ll', 'D_Ww', 'D_Cc', 'D_Ll']

# %%
"""
PD Dataframeからrawをlistとして取り出す


"""
# Out:
# '\n\n\n'
